# %%
# set { } means a set
colors = { "red", "orange", "red", "blue" }

# no double red !!
colors, list(colors)[2]
# Out:
# ({'blue', 'orange', 'red'}, 'red')

# %%
# set removes duplicates
not_unique = [0, 1, 2, 3, 3, 4, 5]
uniqueSet = set(not_unique)

uniqueSet
# Out:
# {0, 1, 2, 3, 4, 5}

# %%
#get second item from set
list(uniqueSet)[1]

#remove item from set
uniqueSet.remove(3)  

uniqueSet
# Out:
# {0, 1, 2, 4, 5}
