# %%
animals = ['cat', 'dog', 'rabbit']

type(animals), animals[0]
# Out:
# (list, 'cat')

# %%
#static. use methods to modify the list
animals.extend(['hamster', 'parrot'])
animals.insert(1, 'turtle')

animals
# Out:
# ['cat', 'turtle', 'dog', 'rabbit', 'hamster', 'parrot']

# %%
#slicing
animals[0:4]
# Out:
# ['cat', 'turtle', 'dog', 'rabbit']

# %%
animals[-2:]
# animals[-2] # single element
# Out:
# ['hamster', 'parrot']

# %%
animals.index('rabbit')
# Out:
# 3
