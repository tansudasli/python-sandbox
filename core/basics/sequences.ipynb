# %% [markdown]
# # Array

# %%
participants = ['ali', 'veli', 'deli']

# %%
# result is () tuple
# , means = tuple
participants, participants[1], len(participants)
# Out:
# (['ali', 'veli', 'deli'], 'veli', 3)

# %%
participants.append('zuheyla')


participants
# Out:
# ['ali', 'veli', 'deli', 'zuheyla']

# %%
participants.extend(['ferman', 'derman', 'azman'])

participants
# Out:
# ['ali', 'veli', 'deli', 'zuheyla', 'ferman', 'derman', 'azman']

# %%
participants[1:3]
# Out:
# ['veli', 'deli']

# %%
index_of_ferman, count_of_ferman, capacity_of_participants = participants.index('ferman'), participants.count('ferman'), len(participants)

index_of_ferman, count_of_ferman, capacity_of_participants
# Out:
# (4, 1, 7)

# %%
participants.sort()

participants
# Out:
# ['ali', 'azman', 'deli', 'derman', 'ferman', 'veli', 'zuheyla']

# %% [markdown]
# # tuple

# %%
data = ('ali', 'veli', 'deli', 'zuheyla', 'ferman', 'derman', 'azman')

data, type(data)
# Out:
# (('ali', 'veli', 'deli', 'zuheyla', 'ferman', 'derman', 'azman'), tuple)

# %%
# tuple unpacking 
(age, years_of_school) = 30, 15

age
# Out:
# 30

# %%
(age, years_of_school) = '30,15'.split(',')

# %%
age, print(age)
# Out:
# 30
# ('30', None)

# %%
# returning as tuple in functions are very useful
def computeOf(x):
    A = x ** 2
    P = 4 * x
    return (A, P)

xsquare, x4 = computeOf(5)

x4
# Out:
# 20

# %% [markdown]
# # dictionary

# %%
# key, value 
dict = {'001':'cat',
        '002':'dog',
        '003':'donkey',
        '004':'monkey',
        '005':'ape'}

#[key] is used to access value
dict['003'], dict
# Out:
# ('donkey',
#  {'001': 'cat', '002': 'dog', '003': 'donkey', '004': 'monkey', '005': 'ape'})

# %%
dict['001'] = 'lazy animal'

dict
# Out:
# {'001': 'lazy animal',
#  '002': 'dog',
#  '003': 'donkey',
#  '004': 'monkey',
#  '005': 'ape'}

# %%
employeesByDepartment = {'hr': 'ali',
                         'acc': ['hasan', 'huseyin']}

employeesByDepartment
# Out:
# {'hr': 'ali', 'acc': ['hasan', 'huseyin']}

# %%
# contains a list
employeesByDepartment['acc']

#employeesByDepartment['acc'][0]
# Out:
# ['hasan', 'huseyin']

# %%
# a nother way to assign values
team = {}

team['1hxzYkt'] = 'mahmut'
team['1HxTYkt'] = 'selma'

team
# Out:
# {'1hxzYkt': 'mahmut', '1HxTYkt': 'selma'}

# %%
team.get('1hxzYkt')
# Out:
# 'mahmut'

# %%
#tenary operator
#generators & comprehensions
square_dict = { x: x*x for x in range(6) }
square_set  = { x*x for x in range(6) }
square_list = [ x*x for x in range(6) ]
square_tuple= tuple( x*x for x in range(6) )    #lazy

square_dict, square_set, square_list, square_tuple
# Out:
# ({0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25},
#  {0, 1, 4, 9, 16, 25},
#  [0, 1, 4, 9, 16, 25],
#  (0, 1, 4, 9, 16, 25))
