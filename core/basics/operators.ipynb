# %%
# div, mod, exponents, boolean, 

16/3,16%3, 5**3, 5**3 == 125, 'friday'[0], 10 != 10
# Out:
# (5.333333333333333, 1, 125, True, 'f', False)

# %%
def compare(y):
    return 'is it 5?' if y == 5 else ('greater than 5' if y > 5 else 'problem :)')

compare(3), compare(10), compare(5)
# Out:
# ('problem :)', 'greater than 5', 'is it 5?')
