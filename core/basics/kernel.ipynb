# %%
# %connect_info

#list kernel ports etc.
# Out:
# {"key":"d0d0ec3f-01c5-43db-979b-936b607b22d3","signature_scheme":"hmac-sha256","transport":"tcp","ip":"127.0.0.1","hb_port":9005,"control_port":9006,"shell_port":9007,"stdin_port":9008,"iopub_port":9009,"kernel_name":"python3140jvsc74a57bd036e5de6d90be7b7a3a3ddd9c65185cb7f794e19b41a32400abf9d42fc8f23759"}
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-v3401b5c6c4f023dc17afe4b77b2cd90841a09a2d5.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.

# %%
# %%bash
# kill -9 $(lsof -i:9000,9001,9002,9003,9004)
#
# #kills any process using ports 9000-9004
# # (jupyter ports if hanging)
