# %%
def summm(x, y):
    return x + y

summm(3, 5)
# Out:
# 8

# %%
#unpacking - return tuple in function
def min_max(items):
    return min(items), max(items)

min_max([1, 2, 3, 4, 5]), min_max({'aa', 'bb', 'cc'})
# Out:
# ((1, 5), ('aa', 'cc'))

# %%
#returning string manipulation
def greet(name):
    return f"hello, {name}"

greet("ali")
# Out:
# 'hello, ali'

# %%
# , means = tupple at everywhere :)
# below, unpacking the tupple into 2 variables !
x, y = min(10, 20, 30), abs(-12)

y
# Out:
# 12

# %%
l = [10, 20, 30]

l
# Out:
# [10, 20, 30]

# %%
# unpacking the tupple into 3 variables !
x,y,z = sum(l), max(l), min(l)

x
# Out:
# 60

# %%
round(5.56, ndigits= 1)
# Out:
# 5.6

# %%
len('math')
# Out:
# 4
