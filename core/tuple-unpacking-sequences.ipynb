# %%
student_tuple = ("tansu", [20, 30 , 50])
student_tuple
# Out:
# ('tansu', [20, 30, 50])

# %%
name, grades = student_tuple
print(f"{name} {grades}")
# Out:
# tansu [20, 30, 50]

# %%
# get indexed list !

colors = ["red", "blue", "orange"]
# Out:
# [(0, 'red'), (1, 'blue'), (2, 'orange')]

# %%
colorsIndexed = list(enumerate(colors))
colorsIndexed

# %%
colorsIndexedTuple = tuple(enumerate(colors))
colorsIndexedTuple
# Out:
# ((0, 'red'), (1, 'blue'), (2, 'orange'))

# %%
# unpack
# Out:
# Traceback (most recent call last):
#
#   File "/Users/tansudasli/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-32-16412b26fa6d>", line 2, in <module>
#     get_ipython().run_line_magic('timeit', '10 2+2')
#
#   File "/Users/tansudasli/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2287, in run_line_magic
#     result = fn(*args,**kwargs)
#
#   File "<decorator-gen-61>", line 2, in timeit
#
#   File "/Users/tansudasli/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#
#   File "/Users/tansudasli/anaconda3/lib/python3.7/site-packages/IPython/core/magics/execution.py", line 1074, in timeit
#     ast_stmt = self.shell.compile.ast_parse(transform(stmt))
#
# ...

# %%
# %%timeit
for i, k in colorsIndexed:
    print(f"{i} {k}")
# Out:
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# 2 orange
# 0 red
# 1 blue
# ...

# %%
#run any shell command
# !ls
# Out:
# collections.ipynb               isOdd.py
# dictionary.ipynb                list.py
# dictionary.py                   list2.py
# dictionary2.py                  set.ipynb
# file.py                         tuple-unpacking-sequences.ipynb
# func.py                         tuple.py
# if-else.py
