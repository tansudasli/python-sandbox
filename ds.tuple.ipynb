# %%
daysOfWeek = ("Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday")
weekendDays = daysOfWeek[5:]

weekendDays
# Out:
# ('Saturday', 'Sunday')

# %%
# , means kinda tuple , handles as tuple
isTuple = 'x', 'y', 'z'

#isTuple == tuple meaningless :)

isTuple
# Out:
# ('x', 'y', 'z')

# %%
students = (
    ("Alice", [24, 82, 100], "turkish"),
    ("Alice", [34, 42, 60], "math"),
    ("Bob", [84, 92, 90], "turkish"),
    ("Bob", [44, 62, 70], "math")
    )

#so flexible to hold different data types
students[0][1][2]  #100
# Out:
# 100

# %%
#unpacking tuples 

# must be 1 record !!
# name, scores, lesson = students.  #not works
name, scores, lesson = students[0]  #first record

name
# Out:
# 'Alice'

# %%
# returning as tuple in functions are very useful
def computeOf(x):
    A = x ** 2
    P = 4 * x
    return (A, P)

xsquare, x4 = computeOf(5)

x4
# Out:
# 20

# %%
# %%time
#cell-magic
print("dd")
# Out:
# dd
# CPU times: user 212 μs, sys: 91 μs, total: 303 μs
# Wall time: 259 μs

# %%
# %%timeit -n3 -r5

print("dd")
# Out:
# dd
# dd
# dd
# dd
# dd
# dd
# dd
# dd
# dd
# dd
# dd
# dd
# dd
# dd
# dd
# The slowest run took 12.52 times longer than the fastest. This could mean that an intermediate result is being cached.
# 23.7 μs ± 32.6 μs per loop (mean ± std. dev. of 5 runs, 3 loops each)
