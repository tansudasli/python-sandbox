# %% [markdown]
# ## numpy - random generators

# %%
#random generator example
# use generators not np.random!
import numpy as np

rng = np.random.default_rng(seed=42)

random_ints = rng.integers(low=0, high=100, size=10)  #array([ 8, 56, 92, 14, 82,  4, 90, 45, 66, 39])
random_ints_2D = rng.integers(low=0, high=100, size=(2,4))  #array([[12, 52, 93, 15],
                                                                #   [72, 61, 21, 83]])  
# count brackets [[......]] = 2d

random_ints_3D = rng.integers(low=0, high=100, size=(2,3,4)) 

random_ints, random_ints_2D, random_ints_3D
# Out:
# (array([ 8, 77, 65, 43, 43, 85,  8, 69, 20,  9]),
#  array([[52, 97, 73, 76],
#         [71, 78, 51, 12]]),
#  array([[[83, 45, 50, 37],
#          [18, 92, 78, 64],
#          [40, 82, 54, 44]],
#
#         [[45, 22,  9, 55],
#          [88,  6, 85, 82],
#          [27, 63, 16, 75]]]))

# %%
# 1d = []
# 2d = [][]
random_ints[0], \
random_ints_2D[0][0] #2d = [][]
# Out:
# (np.int64(8), np.int64(52))

# %%
# 3d = [[[ .... ]]]

random_ints_3D[0] #2d, 3x4 matrix
# Out:
# array([[83, 45, 50, 37],
#        [18, 92, 78, 64],
#        [40, 82, 54, 44]])

# %%
np.mean(random_ints), np.median(random_ints)
# Out:
# (np.float64(42.7), np.float64(43.0))
