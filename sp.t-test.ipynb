# %%
import scipy as sp
from scipy import stats
from numpy import random

# %%
boys = random.randint(0, 100, size=50)
girls = random.randint(40, 100, size=50)

# %% [markdown]
# Look for T-Test for significant diff.

# %%
sp.mean(boys)
# Out:
# 45.46

# %%
sp.mean(girls)
# Out:
# 67.78

# %%
stats.ttest_ind(boys, girls)

#T-Value = -4.4
#P-Value = 0.0000274 < 0.5 (significantly different)
# Out:
# Ttest_indResult(statistic=-4.401109299343111, pvalue=2.7447756548742747e-05)

# %% [markdown]
# calculate regression between temperature and icecream sales
