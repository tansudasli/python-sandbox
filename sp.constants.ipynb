# %%
#
import scipy.constants as const

print(f"Speed of light in vacuum: {round(const.c / 1000)} km/s")
print(f"Planck constant: {const.h} J·s")
print(f"horsepower: {const.horsepower} Watt")
# Out:
# Speed of light in vacuum: 299792 km/s
# Planck constant: 6.62607015e-34 J·s
# horsepower: 745.6998715822701 Watt
